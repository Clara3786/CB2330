# %% [markdown]
# <a href="https://colab.research.google.com/github/Clara3786/CB2330/blob/main/Session1_partB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Harmonic mean:
# $N \Big/ \displaystyle\sum_{i=1}^{N} \frac{1}{x_i}$
#
# It calculates an average for rates

# %%
counts = [
    3473, 2876, 2480, 2445, 1524, 1980, 1237, 3635, 2060, 2386,
    2562, 2109, 1915, 2189, 3094, 1974, 2407, 2653, 2374, 1940,
    1871, 2456, 2140, 2207, 4757, 2882, 3834, 2512, 1663, 2023,
    1222, 591, 2266, 985, 2432, 3248, 2132, 1292, 2490, 3251,
    1979, 2000, 1736, 2612, 2411, 2283, 1324, 1948, 2084, 3840,
    2375, 2223, 2069, 973, 2088, 2541, 6317, 1918, 3863, 1647,
]

# %%
def divide_total_reads(counts):
    """T = one divided by the sum of the counts over every cell."""
    total = 0
    for value in counts:
        total = total + 1/value
    return total

# %%
def harmonic_mean_reads(counts):
    """xbar = N / (1/sum of the counts)."""
    return len(counts) / divide_total_reads(counts)

# %%
calculate = harmonic_mean_reads(counts)
print(calculate)
# Out:
# 2038.2134693113453

# %%
import numpy as np
from scipy.stats import hmean

# %%
harmonic_mean = hmean(counts)

# %%
print(harmonic_mean)
# Out:
# 2038.2134693113455

# %% [markdown]
# The last decimal is different between the two, this might be due to different roundings when Python uses floats.
